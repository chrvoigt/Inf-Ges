# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv('data/search.csv', encoding='latin1')
df.head()
# Out:
#   First Search Time (GMT)  Country ID All Department (APS) or Category  \
# 0     2017-01-04 22:12:00           4                             toys
# 1     2018-01-07 20:21:26           4                              aps
# 2     2016-03-08 21:50:46           4                              aps
# 3     2018-01-07 20:35:20           4                              aps
# 4     2018-04-12 08:07:31           4                              aps
#
#      Site Variant Device Type  Device Model  \
# 0      PC Browser     Desktop   301612268.0
# 1      PC Browser     Desktop   329022669.0
# 2             NaN      Tablet           NaN
# 3      PC Browser     Desktop   329022669.0
# 4  Mobile Browser  Smartphone   515640020.0
#
#   Search Type (Keyword,Visual,Browse)           Session ID    Query ID  \
# 0                                  kw  276-9733532-9164864  1483567919
# 1                                  kw  276-9733532-9164864  1515356485
# ...

# %%
df.describe()
# Out:
#        Country ID  Device Model      Query ID  Prime Customer (Y/N)  \
# count       425.0  3.420000e+02  4.250000e+02            425.000000
# mean          4.0  3.847522e+08  1.500212e+09              0.072941
# std           0.0  1.358886e+08  2.352107e+07              0.260346
# min           4.0  1.965754e+07  1.456179e+09              0.000000
# 25%           4.0  3.247018e+08  1.483565e+09              0.000000
# 50%           4.0  3.385438e+08  1.497562e+09              0.000000
# 75%           4.0  4.320761e+08  1.513115e+09              0.000000
# max           4.0  1.021740e+09  1.547190e+09              1.000000
#
#        Is From External Link (Y/N)  Search From External Site (Y/N)  \
# count                   425.000000                       425.000000
# mean                      0.025882                         0.105882
# std                       0.158971                         0.308050
# min                       0.000000                         0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425 entries, 0 to 424
# Data columns (total 61 columns):
# First Search Time (GMT)                   425 non-null object
# Country ID                                425 non-null int64
# All Department (APS) or Category          425 non-null object
# Site Variant                              356 non-null object
# Device Type                               425 non-null object
# Device Model                              342 non-null float64
# Search Type (Keyword,Visual,Browse)       425 non-null object
# Session ID                                425 non-null object
# Query ID                                  425 non-null int64
# Prime Customer (Y/N)                      425 non-null int64
# Is From External Link (Y/N)               425 non-null int64
# Search From External Site (Y/N)           425 non-null int64
# First Search Query String                 332 non-null object
# ...

# %%
df[10:20].Keywords
# Out:
# 10                          NaN
# 11              laptop rucksack
# 12                     rucksack
# 13                          NaN
# 14           playmobil soldaten
# 15                  co-creation
# 16                     iceage 2
# 17                kleines leben
# 18    kleines leben morgenstern
# 19             washi tape glitz
# Name: Keywords, dtype: object

# %%
subset = df[['All Department (APS) or Category', 'Keywords', 'Is From External Link (Y/N)','Search From External Site (Y/N)','Paid Purchase (Y/N)']]

subset.columns = ['category','keyword','ext_link','ext_search','purchase']
subset.tail(10)
# Out:
#           category                 keyword  ext_link  ext_search  purchase
# 415    electronics               projektor         0           0         0
# 416           baby          kleinkind hose         0           0         0
# 417            aps            flame sensor         0           0         0
# 418      computers      samsonite rucksack         0           0         0
# 419            aps  ultimaking ultimaker 2         0           1         0
# 420  specialty-aps                     NaN         0           0         0
# 421    electronics                ipad pro         0           0         0
# 422      computers      brother hl 3152cdw         0           0         0
# 423            aps   winter fuÃsack buggy         0           0         0
# 424       clothing     lederjacken mÃ¤nner         0           0         0
